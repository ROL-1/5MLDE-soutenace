# %%
import pandas as pd
data = pd.read_csv("../data/winequality.csv")
data.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
import yaml
from pprint import pprint

with open("../gx/great_expectations.yml", "r") as stream:
    try:
        ge_config = yaml.safe_load(stream)
    except yaml.YAMLError as exc:
        print(exc)

pprint(ge_config["datasources"], indent=0)
# Out:
# {'winequality_datasource': {'class_name': 'Datasource',
#                           'data_connectors': {'default_inferred_data_connector_name': {'base_directory': '..\\data',
#                                                                                      'class_name': 'InferredAssetFilesystemDataConnector',
#                                                                                      'default_regex': {'group_names': ['data_asset_name'],
#                                                                                                       'pattern': '(.*)'},
#                                                                                      'module_name': 'great_expectations.datasource.data_connector'},
#                                              'default_runtime_data_connector_name': {'assets': {'my_runtime_asset_name': {'batch_identifiers': ['runtime_batch_identifier_name'],
# ...

# %%
import json

# Open JSON file
with open("../gx/expectations/winequality_expectation_suite.json", "r") as f:
    data = json.load(f)

# Pretty print JSON data
print(json.dumps(data, indent=4))
# Out:
# {
#     "data_asset_type": null,
#     "expectation_suite_name": "winequality_expectation_suite",
#     "expectations": [
#         {
#             "expectation_type": "expect_table_row_count_to_be_between",
#             "kwargs": {
#                 "max_value": 6497,
#                 "min_value": 6497
#             },
#             "meta": {
#                 "profiler_details": {
#                     "metric_configuration": {
#                         "domain_kwargs": {},
#                         "metric_name": "table.row_count",
#                         "metric_value_kwargs": null
#                     },
#                     "num_batches": 1
#                 }
#             }
#         },
#         {
#             "expectation_type": "expect_table_columns_to_match_set",
#             "kwargs": {
#                 "column_set": [
#                     "total sulfur dioxide",
#                     "citric acid",
#                     "quality",
# ...

# %%
with open("../gx/checkpoints/wine_quality_checkpoint.yml", "r") as stream:
    try:
        chkp_config = yaml.safe_load(stream)
    except yaml.YAMLError as exc:
        print(exc)

pprint(chkp_config)
# Out:
# {'action_list': [{'action': {'class_name': 'StoreValidationResultAction'},
#                   'name': 'store_validation_result'},
#                  {'action': {'class_name': 'StoreEvaluationParametersAction'},
#                   'name': 'store_evaluation_params'},
#                  {'action': {'class_name': 'UpdateDataDocsAction'},
#                   'name': 'update_data_docs'}],
#  'batch_request': {},
#  'class_name': 'SimpleCheckpoint',
#  'config_version': 1.0,
#  'evaluation_parameters': {},
#  'expectation_suite_ge_cloud_id': None,
#  'expectation_suite_name': None,
#  'ge_cloud_id': None,
#  'module_name': 'great_expectations.checkpoint',
#  'name': 'wine_quality_checkpoint',
#  'profilers': [],
#  'run_name_template': '%Y%m%d-%H%M%S-my-run-name-template',
#  'runtime_configuration': {},
#  'template_name': None,
#  'validations': [{'batch_request': {'data_asset_name': 'winequality.csv',
# ...

# %%
import great_expectations as gx

# %%
context = gx.data_context.DataContext()
print("list_expectation_suite_names", context.list_expectation_suite_names())
print("datasource names", [datasource["name"] for datasource in context.list_datasources()])
print("checkpoints", context.list_checkpoints())
# Out:
# list_expectation_suite_names ['winequality_expectation_suite']
# datasource names ['winequality_datasource']
# checkpoints ['wine_quality_checkpoint']

# %%
context.run_checkpoint(checkpoint_name="wine_quality_checkpoint")
# Out:
# Calculating Metrics:   0%|          | 0/211 [00:00<?, ?it/s]
# {
#   "run_id": {
#     "run_name": "20240126-151018-my-run-name-template",
#     "run_time": "2024-01-26T16:10:18.155995+01:00"
#   },
#   "run_results": {
#     "ValidationResultIdentifier::winequality_expectation_suite/20240126-151018-my-run-name-template/20240126T151018.155995Z/a7b19f8479279acbf7f8362dd178a48f": {
#       "validation_result": {
#         "statistics": {
#           "evaluated_expectations": 103,
#           "successful_expectations": 103,
#           "unsuccessful_expectations": 0,
#           "success_percent": 100.0
#         },
#         "success": true,
#         "meta": {
#           "great_expectations_version": "0.18.8",
#           "expectation_suite_name": "winequality_expectation_suite",
#           "run_id": {
#             "run_name": "20240126-151018-my-run-name-template",
#             "run_time": "2024-01-26T16:10:18.155995+01:00"
#           },
#           "batch_spec": {
# ...
